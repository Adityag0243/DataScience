# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 217.9 kB/s eta 0:01:11
#    ---------------------------------------- 0.0/15.4 MB 217.9 kB/s eta 0:01:11
#    ---------------------------------------- 0.1/15.4 MB 238.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/15.4 MB 238.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/15.4 MB 238.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/15.4 MB 238.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/15.4 MB 238.1 kB/s eta 0:01:05
#    ---------------------------------------- 0.1/15.4 MB 157.5 kB/s eta 0:01:38
#    ---------------------------------------- 0.1/15.4 MB 157.5 kB/s eta 0:01:38
# ...

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost' , user='root',passwd="")

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show database")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'database' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %%
cursor.execute("show databases")

# %%
list_of_DBs=cursor.fetchall()

# %%
list_of_DBs
# Out:
# [('hello',),
#  ('hello123',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
list_of_DBs[1]
# Out:
# ('hello123',)

# %%
mydb

# %%
cursor.execute("create database hello321")

# %%
cursor.execute("use hello321")

# %%
cursor.execute("create table tablepython(col1 int , col2 varchar(20))")

# %%
cursor.execute("show tables")

# %%
cursor.execute("fetchall")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cursor.execute("fetchall")
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:347, in CMySQLCursor.execute(self, operation, params, multi)
#     345 except (ProgrammingError, ReferenceError) as err:
#     346     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 347 self._cnx.handle_unread_result()
#     349 stmt = b""
#     350 self.reset()
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:990, in CMySQLConnection.handle_unread_result(self, prepared)
#     988     self.consume_results()
#     989 elif unread_result:
# --> 990     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
cursor.fetchall()
# Out:
# [('tablepython',)]

# %%
cursor.execute("select * from tablepython")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('insert into hello321.tablepython values(1,"Aditya")')     #using single quote show that do not overlap with Aditya's double quote

# %%
cursor.execute("select * from tablepython")
cursor.fetchall()
# Out:
# [(1, 'Aditya'), (1, 'Aditya')]

# %%
cursor.execute('insert into tablepython values(1,"Aditya"),(2,"Aadhar"),(3,"Ayush")')

# %%
cursor.execute("select * from tablepython")
cursor.fetchall()
# Out:
# [(1, 'Aditya'), (1, 'Aditya'), (1, 'Aditya'), (2, 'Aadhar'), (3, 'Ayush')]

# %%
cursor.execute("select col1 from tablepython")
cursor.fetchall()
# Out:
# [(1,), (1,), (1,), (2,), (3,)]

# %%
cursor.execute("select col2 from tablepython")
cursor.fetchall()
# Out:
# [('Aditya',), ('Aditya',), ('Aditya',), ('Aadhar',), ('Ayush',)]
