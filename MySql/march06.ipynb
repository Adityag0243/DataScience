# %%
data=open("hw.txt")    #by default read mode

# %%
data
# Out:
# <_io.TextIOWrapper name='hw.txt' mode='r' encoding='cp1252'>

# %%
read_data=data.read()

# %%
read_data
# Out:
# 'different role for website \ntask 1 and 2 in ds in pandas\n\ndo while real life application \n\n\nfujnction for bank on console.....upi atm taptopay limit transfer type india outside india etc...\ncalculate tax\nis js func work on call by value or reference....... and why??\nkeyword in js\n\n\n\n\n\nflask'

# %%
data.close()

# %%
data=open("hw.txt","w")
data.write('differennnnnrd in js \n flaskeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee')
# Out:
# 73

# %%
data
# Out:
# <_io.TextIOWrapper name='hw.txt' mode='w' encoding='cp1252'>

# %%
with open("hw.txt","r") as data1:
    read_content= data1.read()
    print(read_content)
# Out:
# differennnnnnnt role for website
#  task 1 and 2 in ds in pandas.
#  do while real life application.
# fujnction for bank on console.....upi atm taptopay limit transfer type india outside india etc...
# calculate tax
# is js func work on call by value or reference....... and why??
# keyword in js
#  flaskeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee

# %%
import mysql.connector as conn

# %%
mydatabase=conn.connect(host="localhost" , user="root" , passwd="1234")

# %%
mydatabase

# %%
my_cursor=mydatabase.cursor()

# %%
my_cursor.execute("Show databases")

# %%
my_cursor.fetchall()
# Out:
# [('cardekho',),
#  ('hellopw',),
#  ('information_schema',),
#  ('mysql',),
#  ('newpwioi',),
#  ('performance_schema',),
#  ('pw',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('uploaderdb',),
#  ('world',)]

# %%
my_cursor.execute("create database UploaderDB")

# %%
my_cursor.execute("Show databases")
my_cursor.fetchall()
# Out:
# [('cardekho',),
#  ('hellopw',),
#  ('information_schema',),
#  ('mysql',),
#  ('newpwioi',),
#  ('performance_schema',),
#  ('pw',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('uploaderdb',),
#  ('world',)]

# %%
my_cursor.execute("use uploaderdb")

# %%
import csv
with open("glass.data" , "r") as my_data:
    glass_data=csv.reader(my_data , delimiter='\n')
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
import csv
with open("glass.data" , "r") as my_data:
    glass_data=csv.reader(my_data , delimiter='\n')
    for i in glass_data:
        print(i[0])
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
import csv
with open("wine.csv" , "r") as my_data1:
    glass_data1=csv.reader(my_data1 , delimiter='\n')
    for i in glass_data1:
        print(i[0])
# Out:
# Row Labels,Sum of GDP (billion US$ real 1990),Sum of Wine produced (ML),Sum of Per capita wine expenditure (US$ 2015)
# AME,1898.337042,1297.607,145.552173
# Algeria,158.756184,52,43.94809458
# Morocco,161.8063508,37,13.18859682
# Other AME,,35,2.209521378
# South Africa,305.5519791,1107.4,37.15827027
# Tunisia,103.0258805,21.5,31.68381691
# Turkey,1169.196648,44.707,17.36387305
# ANZ,777.6355994,1518.845333,633.29242
# Australia,682.1627023,1229.178667,296.4089797
# New Zealand,95.47289704,289.6666667,336.8834403
# APA,27762.80697,2111.293424,430.1038654
# China,15104.21122,1025.178825,28.9570589
# Hong Kong,252.645131,,71.56373873
# India,5711.512635,21.20583098,0.252190894
# Japan,2890.94758,16.33066667,142.9118944
# Korea,1220.887765,,49.80252327
# Malaysia,376.8729519,,10.55751128
# Other APA,,1048.578102,1.431629301
# Philippines,383.7036766,,2.873141657
# Singapore,194.3156754,,87.76861141
# Taiwan,662.814,,23.17376592
# Thailand,964.8963346,,10.8117997
# ...

# %%
my_cursor.execute("create table uploader_wine(countryname varchar(30))")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'uploader_wine' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 my_cursor.execute("create table uploader_wine(countryname varchar(30))")
#
# ...

# %%
my_cursor.execute("Show tables")
my_cursor.fetchall()
# Out:
# [('uploader_wine',)]

# %%
my_cursor.execute("Show databases")
my_cursor.fetchall()
# Out:
# [('cardekho',),
#  ('hellopw',),
#  ('information_schema',),
#  ('mysql',),
#  ('newpwioi',),
#  ('performance_schema',),
#  ('pw',),
#  ('sakila',),
#  ('sys',),
#  ('testdb',),
#  ('uploaderdb',),
#  ('world',)]

# %%
my_cursor.execute("use uploaderdb")

# %%
my_cursor.fetchall()
# Out:
# []

# %%
my_cursor.execute("Show tables")

# %%
my_cursor.fetchall()
# Out:
# [('uploader_wine',)]

# %%
my_cursor.execute("select * from uploader_wine")
my_cursor.fetchall()
# Out:
# []

# %%
# Alter table uploader_wine 
# add gdp float
# data4

query = "ALTER TABLE uploader_wine ADD gdp float"
my_cursor.execute(query)

# %%
query = "ALTER TABLE uploader_wine ADD wine_production float"
my_cursor.execute(query)

# %%
query = "ALTER TABLE uploader_wine ADD wine_expenditure float"
my_cursor.execute(query)

# %%
# my_cursor.execute("show uploader_wine.description")
# my_cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 my_cursor.commit()
#
# AttributeError: 'CMySQLCursor' object has no attribute 'commit'

# %%
mydatabase.commit()
