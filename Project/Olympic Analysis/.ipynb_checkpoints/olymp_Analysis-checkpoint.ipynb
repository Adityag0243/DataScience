# %%
import pandas as pd
df=pd.read_csv("Olympics.csv")
#Que 1 retrievel of record
df
# Out:
#     id                                name sex  age  height  weight  \
# 0    1                           A Dijiang   M   24   180.0    80.0
# 1    2                            A Lamusi   M   23   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M   24     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M   34     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F   21   185.0    82.0
# ..  ..                                 ...  ..  ...     ...     ...
# 95  32                Olav Augunson Aarnes   M   23     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M   24   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M   28   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M   30   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M   24   190.0    98.0
#
#               team  noc        games  year  season       city          sport  \
# ...

# %%
#que 2
NameMedal=df[["name" ,"medal"]]
NameMedal
# Out:
#                                   name medal
# 0                            A Dijiang   NaN
# 1                             A Lamusi   NaN
# 2                  Gunnar Nielsen Aaby   NaN
# 3                 Edgar Lindenau Aabye  Gold
# 4             Christine Jacoba Aaftink   NaN
# ..                                 ...   ...
# 95                Olav Augunson Aarnes   NaN
# 96                 Mika Lauri Aarnikka   NaN
# 97                 Mika Lauri Aarnikka   NaN
# 98  Jamale (Djamel-) Aarrass (Ahrass-)   NaN
# 99              Dagfinn Sverre Aarskog   NaN
#
# [100 rows x 2 columns]

# %%
#Que 3 total number of Athelethe(unique name in name column)
df.name.nunique()
# Out:
# 35

# %%
#Que 4 , All record of those who won GOLD using loc for putting condition based retrivel
Goldmedalist=df.loc[df.medal == "Gold"]
Goldmedalist
# Out:
#     id                       name sex  age  height  weight            team  \
# 3    4       Edgar Lindenau Aabye   M   34     NaN     NaN  Denmark/Sweden
# 42  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 44  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 48  17    Paavo Johannes Aaltonen   M   28   175.0    64.0         Finland
# 60  20         Kjetil Andr Aamodt   M   20   176.0    85.0          Norway
# 73  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 76  20         Kjetil Andr Aamodt   M   30   176.0    85.0          Norway
# 78  20         Kjetil Andr Aamodt   M   34   176.0    85.0          Norway
# 79  21  Ragnhild Margrethe Aamodt   F   27   163.0     NaN          Norway
#
#     noc        games  year  season            city          sport  \
# 3   DEN  1900 Summer  1900  Summer           Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer          London     Gymnastics
# ...

# %%
#Que 5    detail of athelete who won silver ordered by year
Silvermedalist=df.loc[df.medal == "Silver"]
Silvermedalist.sort_values("year")
# Out:
#     id                name sex  age  height  weight         team  noc  \
# 86  25    Alf Lied Aanning   M   24     NaN     NaN       Norway  NOR
# 63  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 67  20  Kjetil Andr Aamodt   M   22   176.0    85.0       Norway  NOR
# 92  30    Pepijn Aardewijn   M   26   189.0    72.0  Netherlands  NED
#
#           games  year  season         city          sport  \
# 86  1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 63  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67  1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 92  1996 Summer  1996  Summer      Atlanta         Rowing
#
#                                               event   medal
# 86  "Gymnastics Men's Team All-Around, Free System"  Silver
# 63                     Alpine Skiing Men's Downhill  Silver
# 67                     Alpine Skiing Men's Combined  Silver
# 92           Rowing Men's Lightweight Double Sculls  Silver

# %%
#Que 6  country wise medal won 
df.groupby('team')['medal'].count()     #will give country vs total medal count
   
df1=df[['team','medal','sport']]
df1
pivot_table=df1.pivot_table(values="medal" , index="team",columns="medal",aggfunc='count')  
pivot_table

#showing only 4 country bcz all other wpn zero total medals
# Out:
# medal           Bronze  Gold  Silver
# team
# Denmark/Sweden     NaN   1.0     NaN
# Finland            5.0   3.0     NaN
# Netherlands        1.0   NaN     1.0
# Norway             2.0   5.0     3.0

# %%
#que 7 Identify countries that have won more than 50 Gold medals.

df.medal.count()    # 21


#as total medal count==21 which is < 50 then no country have medal>50
# Out:
# 21

# %%
#que 8  Olympics data with country information to show the total number of medals won by
#countries with a population over 10 million.

df.groupby('team')['medal'].count()


#there is no information about contries population in data set
# Out:
# team
# China              0
# Denmark            0
# Denmark/Sweden     1
# Estonia            0
# Finland            8
# France             0
# Netherlands        2
# Norway            10
# Romania            0
# United States      0
# Name: medal, dtype: int64

# %%
# que 9 Find the athlete who has won the most medals

df2=df.groupby('name')['medal'].count()   #store each name and corresponding medal counts
# df2.columns=["Name","No_of_Medal"]
df2.idxmax()            # idxmax will give name of max medal
# Out:
# 'Kjetil Andr Aamodt'

# %%
#que 10 List all events that include the term 'Freestyle' in their name
a=df.name=="*freestyle"
a.nunique()                       # can't able to solve
# Out:
# 1

# %%
#que 11 Find the top 3 athletes by the total number of medals won in each sport.


df3=df.groupby('name')['medal'].count()
df3=df3.sort_values(ascending=False).head(3)
df3=pd.DataFrame(df3)
df3
# Out:
#                          medal
# name
# Kjetil Andr Aamodt           8
# Paavo Johannes Aaltonen      5
# Arvo Ossian Aaltonen         2

# %%
#que 11 continue.....
#23 unique sports and total data 100 and same player played many games that's why we haen't enough data to show top three athlete per sport 

df.groupby(['name','sport'])['medal'].count()
# Out:
# name                                  sport
# A Dijiang                             Basketball              0
# A Lamusi                              Judo                    0
# Agnes Erika Aanonsen (-Eyde)          Luge                    0
# Alf Lied Aanning                      Gymnastics              1
# Andreea Aanei                         Weightlifting           0
# Antti Sami Aalto                      Ice Hockey              0
# Arvo Ossian Aaltonen                  Swimming                2
# Christine Jacoba Aaftink              Speed Skating           0
# Cornelia \Cor\" Aalten (-Strannood)"  Athletics               0
# Dagfinn Sverre Aarskog                Bobsleigh               0
# Edgar Lindenau Aabye                  Tug-Of-War              1
# Einar Ferdinand \Einari\" Aalto"      Swimming                0
# Evald rma (rman-)                     Athletics               0
# Fritz Aanes                           Wrestling               0
# ...

# %%
#que 12   List athletes who won more than one medal in a single Olympic year.


pv_table=df.pivot_table(index=["year","name"],values="medal" ,aggfunc='count')     #year wise each player name and medal count 
df4=pd.DataFrame(pv_table)                 #pv_table into a dataframe
df4.loc[df4.medal>1]                  #now taking those data only whose medal is more than one , year column for reference
# Out:
#                               medal
# year name
# 1920 Arvo Ossian Aaltonen         2
# 1948 Paavo Johannes Aaltonen      4
# 1992 Kjetil Andr Aamodt           2
# 1994 Kjetil Andr Aamodt           3
# 2002 Kjetil Andr Aamodt           2

# %%
#que 13 Identify countries that have won gold medals in both Summer and Winter Olympics
#(assuming a 'Season' column exists).

pv_table2=df.pivot_table(index=["team"],columns="season",values="medal" ,aggfunc='count')
pv_table2.loc[(pv_table2.Summer>0) & (pv_table2.Winter>0)]
# Out:
# season   Summer  Winter
# team
# Finland     7.0     1.0
# Norway      2.0     8.0

# %%
#que 14 Show the year difference between the first and last medal won by each country.


pv_table3=df.pivot_table(index=["team","year"],values="medal" ,aggfunc='count')
pv_table3.loc[pv_table3.medal>0]


#now i don't know how to calculate country vs difference btw first and last year
# Out:
#                      medal
# team           year
# Denmark/Sweden 1900      1
# Finland        1920      2
#                1948      4
#                1952      1
#                2014      1
# Netherlands    1988      1
#                1996      1
# Norway         1920      1
#                1992      2
#                1994      3
#                2002      2
#                2006      1
#                2008      1

# %%
#Que 15 Calculate the average number of medals won per athlete for each country.

pv_table4=df.pivot_table(index=["team"],values=["medal","name"] ,aggfunc="count")
pv_table4.columns=["Total_medal","Total_player"]
ds=pv_table4['Total_medal']/pv_table4['Total_player']
ds=pd.DataFrame(ds)
ds.columns=['Per Athelete Average medal Won']
ds
# Out:
#                 Per Athelete Average medal Won
# team
# China                                 0.000000
# Denmark                               0.000000
# Denmark/Sweden                        1.000000
# Estonia                               0.000000
# Finland                               0.242424
# France                                0.000000
# Netherlands                           0.166667
# Norway                                0.312500
# Romania                               0.000000
# United States                         0.000000

# %%
#que 16 List countries that have won medals in more than 10 different sports.
pv_table3.loc[pv_table3.medal>0]

#by this we can see no contry won 10+ medal norway have equal to 10 so no chances that they won more than 10 games / sports
# Out:
#                      medal
# team           year
# Denmark/Sweden 1900      1
# Finland        1920      2
#                1948      4
#                1952      1
#                2014      1
# Netherlands    1988      1
#                1996      1
# Norway         1920      1
#                1992      2
#                1994      3
#                2002      2
#                2006      1
#                2008      1
