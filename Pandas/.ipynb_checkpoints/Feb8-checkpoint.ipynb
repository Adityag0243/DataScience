# %%
import pandas as pd

# %%
datacar=pd.read_csv("cardekho_dataset.csv")

# %%
datacar
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
datajson=pd.read_json("unece.json")

# %%
datajson
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %%
dataexcel=pd.read_excel("titanic_modified_NA.xlsx")

# %%
dataexcel
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
datacovid=pd.read_csv("COVID19Cases.csv")
# Out:
# C:\Users\mradi\AppData\Local\Temp\ipykernel_10488\1199716535.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   datacovid=pd.read_csv("COVID19Cases.csv")

# %%
datacovid=pd.read_csv(Desktop/DAPython/DA_NOTES/Pandas/COVID19Cases.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 datacovid=pd.read_csv(Desktop/DAPython/DA_NOTES/Pandas/COVID19Cases.csv)
#
# NameError: name 'Desktop' is not defined

# %%
datac=pd.read_csv(COVID19Cases.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 datac=pd.read_csv(COVID19Cases.csv)
#
# NameError: name 'COVID19Cases' is not defined

# %%
datac=pd.read_csv('COVID19Cases.csv' , low_memory=False)

# %%
datac
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %%
datacardekho=pd.read_csv(https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/cardekho_dataset.csv)
# Out:
#   Cell In[29], line 1
#     datacardekho=pd.read_csv(https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/cardekho_dataset.csv)
#                                   ^
# SyntaxError: invalid syntax

# %%
datacardekho=pd.read_csv("https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/cardekho_dataset.csv")

# %%
datacardekho
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
datahtml=pd.read_html("index.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 datahtml=pd.read_html("index.html")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1208 check_dtype_backend(dtype_backend)
#    1210 io = stringify_path(io)
# -> 1212 return _parse(
#    1213     flavor=flavor,
#    1214     io=io,
#    1215     match=match,
#    1216     header=header,
#    1217     index_col=index_col,
#    1218     skiprows=skiprows,
#    1219     parse_dates=parse_dates,
#    1220     thousands=thousands,
#    1221     attrs=attrs,
#    1222     encoding=encoding,
#    1223     decimal=decimal,
#    1224     converters=converters,
#    1225     na_values=na_values,
# ...

# %%
datahtml=pd.read_html("http://127.0.0.1:5500/Resume_v1/day4/index.html")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
datac
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %% [markdown]
# ######INSIGHT 1

# %%
datac.Case_Type.value_counts()
# Out:
# Case_Type
# Confirmed    475335
# Deaths       475335
# Name: count, dtype: int64

# %% [markdown]
# ######INSIGHT 2

# %%
datac.Country_Region.value_counts()
# Out:
# Country_Region
# US                879930
# China               8910
# Canada              3240
# France              2970
# United Kingdom      2970
#                    ...
# Uganda               270
# Barbados             270
# Djibouti             270
# Norway               270
# Guatemala            270
# Name: count, Length: 187, dtype: int64

# %%
x=pd.crosstab(datac.Country_Region,datac.Case_Type,margins=True)
x
# Out:
# Case_Type       Confirmed  Deaths     All
# Country_Region
# Afghanistan           135     135     270
# Albania               135     135     270
# Algeria               135     135     270
# Andorra               135     135     270
# Angola                135     135     270
# ...                   ...     ...     ...
# Western Sahara        135     135     270
# Yemen                 135     135     270
# Zambia                135     135     270
# Zimbabwe              135     135     270
# All                475335  475335  950670
#
# [188 rows x 3 columns]

# %%
datac.Date.value_counts()
# Out:
# Date
# 5/22/2020    7042
# 5/4/2020     7042
# 2/16/2020    7042
# 6/3/2020     7042
# 2/4/2020     7042
#              ...
# 2/8/2020     7042
# 4/24/2020    7042
# 5/28/2020    7042
# 4/17/2020    7042
# 1/22/2020    7042
# Name: count, Length: 135, dtype: int64

# %%
m=datac.Date.sort_values()
m
# Out:
# 950669    1/22/2020
# 900061    1/22/2020
# 900062    1/22/2020
# 900063    1/22/2020
# 900064    1/22/2020
#             ...
# 127651     6/4/2020
# 941062     6/4/2020
# 127704     6/4/2020
# 805332     6/4/2020
# 194945     6/4/2020
# Name: Date, Length: 950670, dtype: object

# %%
m.value_counts()
# Out:
# Date
# 1/22/2020    7042
# 4/23/2020    7042
# 4/9/2020     7042
# 4/8/2020     7042
# 4/7/2020     7042
#              ...
# 3/1/2020     7042
# 2/9/2020     7042
# 2/8/2020     7042
# 2/7/2020     7042
# 6/4/2020     7042
# Name: count, Length: 135, dtype: int64

# %% [markdown]
# #insight3 ####################################################################

# %%
pd.crosstab(datac.Case_Type,datac.Date,margins=True)
# Out:
# Date       1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  \
# Case_Type
# Confirmed       3521       3521       3521       3521       3521       3521
# Deaths          3521       3521       3521       3521       3521       3521
# All             7042       7042       7042       7042       7042       7042
#
# Date       1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  5/5/2020  \
# Case_Type                                              ...
# Confirmed       3521       3521       3521       3521  ...      3521
# Deaths          3521       3521       3521       3521  ...      3521
# All             7042       7042       7042       7042  ...      7042
#
# Date       5/6/2020  5/7/2020  5/8/2020  5/9/2020  6/1/2020  6/2/2020  \
# Case_Type
# Confirmed      3521      3521      3521      3521      3521      3521
# Deaths         3521      3521      3521      3521      3521      3521
# All            7042      7042      7042      7042      7042      7042
#
# ...

# %%
datac.describe()
# Out:
#        People_Total_Tested_Count          Cases     Difference           FIPS  \
# count               6.048000e+03  950670.000000  950670.000000  849690.000000
# mean                1.672996e+05     273.518654       7.388438   30335.484906
# std                 2.643341e+05    5187.497792     166.491030   15196.097280
# min                 3.000000e+00       0.000000  -10034.000000      60.000000
# 25%                 2.980700e+04       0.000000       0.000000   18169.000000
# 50%                 7.798700e+04       0.000000       0.000000   29171.000000
# 75%                 1.897678e+05       4.000000       0.000000   45079.000000
# max                 2.293032e+06  614941.000000   33274.000000   56045.000000
#
#                  Lat           Long  Population_Count  \
# count  921780.000000  921780.000000      9.217800e+05
# mean       37.115970     -83.442661      2.260264e+06
# std         9.763286      38.621432      2.661885e+07
# ...
