# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
game=pd.read_csv("VGsales.csv")

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.Genre
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16593        Platform
# 16594         Shooter
# 16595          Racing
# 16596          Puzzle
# 16597        Platform
# Name: Genre, Length: 16598, dtype: object

# %%
game.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
game.JP_Sales.describe()
# Out:
# count    16598.000000
# mean         0.077782
# std          0.309291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_Sales, dtype: float64

# %%
game.shape
# Out:
# (16598, 11)

# %%
game.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
game.Genre.value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %% [markdown]
# All this is use for EXPLORATORY DATA ANALYSIS using this library

# %%
game.Genre.value_counts(normalize=True) #normalize=frequency/n(relative frequency)
# Out:
# Genre
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: proportion, dtype: float64

# %% [markdown]
# #############################################################################################

# %%
idst=pd.read_csv("industry.csv")

# %%
idst
# Out:
#                          Industry
# 0              Accounting/Finance
# 1    Advertising/Public Relations
# 2              Aerospace/Aviation
# 3   Arts/Entertainment/Publishing
# 4                      Automotive
# 5                Banking/Mortgage
# 6            Business Development
# 7            Business Opportunity
# 8         Clerical/Administrative
# 9         Construction/Facilities
# 10                 Consumer Goods
# 11               Customer Service
# 12             Education/Training
# 13               Energy/Utilities
# 14                    Engineering
# 15            Government/Military
# 16                          Green
# 17                     Healthcare
# 18             Hospitality/Travel
# 19                Human Resources
# 20       Installation/Maintenance
# 21                      Insurance
# 22                       Internet
# 23                Job Search Aids
# 24       Law Enforcement/Security
# 25                          Legal
# ...

# %%
people=pd.read_csv("people.csv")

# %%
people
# Out:
#         Index          User Id First Name Last Name     Sex  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2           3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3           4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4           5  9C4Df1246ddf543     Angela      Shea    Male
# ...       ...              ...        ...       ...     ...
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# ...

# %%
people.rename(columns={"Sex":"Gender"}, inplace=True)

# %%
people
# Out:
#         Index          User Id First Name Last Name  Gender  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2           3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3           4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4           5  9C4Df1246ddf543     Angela      Shea    Male
# ...       ...              ...        ...       ...     ...
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# ...

# %%
people.Gender
# Out:
# 0          Male
# 1          Male
# 2        Female
# 3        Female
# 4          Male
#           ...
# 99995      Male
# 99996      Male
# 99997      Male
# 99998    Female
# 99999      Male
# Name: Gender, Length: 100000, dtype: object

# %%
people.Gender.value_counts()
# Out:
# Gender
# Female    50152
# Male      49848
# Name: count, dtype: int64

# %%
people.describe()
# Out:
#                Index
# count  100000.000000
# mean    50000.500000
# std     28867.657797
# min         1.000000
# 25%     25000.750000
# 50%     50000.500000
# 75%     75000.250000
# max    100000.000000

# %%
people.Gender.describe()
# Out:
# count     100000
# unique         2
# top       Female
# freq       50152
# Name: Gender, dtype: object

# %%
people.Gender.value_counts(normalize=True)
# Out:
# Gender
# Female    0.50152
# Male      0.49848
# Name: proportion, dtype: float64

# %%
people.head()
# Out:
#    Index          User Id First Name Last Name  Gender  \
# 0      1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1      2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2      3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3      4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4      5  9C4Df1246ddf543     Angela      Shea    Male
#
#                         Email                  Phone Date of birth  \
# 0     clintongood@example.org           360-423-5286    1972-01-17
# 1  clairebradshaw@example.org             9062423229    1931-01-31
# 2    johnnybooker@example.org  001-149-154-0679x1617    2018-02-10
# 3           wkhan@example.org     870.294.7563x20939    1938-06-14
# 4  reginaldgarner@example.com           242.442.2978    1971-11-22
#
#                        Job Title
# 0        Teacher, primary school
# 1  Development worker, community
# 2              Ceramics designer
# 3     Civil engineer, consulting
# 4      Health and safety adviser

# %%
people.tail()
# Out:
#         Index          User Id First Name Last Name  Gender  \
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                 Phone Date of birth  \
# 99995  zacharygalloway@example.net      971-408-5795x791    2015-09-02
# 99996            qkane@example.org  001-183-966-1623x446    1978-01-30
# 99997          jenny91@example.com            3010820886    1939-07-11
# 99998          imcneil@example.com         (753)522-4673    1942-02-05
# 99999             emay@example.net      357.974.5692x909    1918-05-30
#
#                                 Job Title
# 99995                   Designer, graphic
# 99996                      Cytogeneticist
# 99997               Engineering geologist
# ...

# %%
people.tail(3)
# Out:
#         Index          User Id First Name Last Name  Gender  \
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                      Email             Phone Date of birth  \
# 99997  jenny91@example.com        3010820886    1939-07-11
# 99998  imcneil@example.com     (753)522-4673    1942-02-05
# 99999     emay@example.net  357.974.5692x909    1918-05-30
#
#                                 Job Title
# 99997               Engineering geologist
# 99998             Clinical cytogeneticist
# 99999  Teacher, special educational needs

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
people.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
people.Gender.nunique()           #no of unique
# Out:
# 2

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
pd.crosstab(game.Genre,game.Publisher)
# Out:
# Publisher     10TACLE Studios  1C Company  20th Century Fox Video Games  \
# Genre
# Action                      0           0                             4
# Adventure                   1           0                             0
# Fighting                    0           0                             0
# Misc                        0           0                             0
# Platform                    0           0                             0
# Puzzle                      1           0                             0
# Racing                      0           1                             0
# Role-Playing                0           1                             0
# Shooter                     0           0                             1
# Simulation                  0           0                             0
# Sports                      0           0                             0
# Strategy                    1           1                             0
#
# ...

# %%
pd.crosstab(game.Genre,game.Year ,margins=True)           #margin true krne se niche subtotal aa rha hai
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# ...

# %%
x=pd.crosstab(game.Genre,game.Year)
x.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
x=pd.crosstab(game.Genre,game.Year)
x.plot(kind="hist",stack=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 2
#       1 x=pd.crosstab(game.Genre,game.Year)
# ----> 2 x.plot(kind="hist",stack=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
# ...

# %%
people
# Out:
#         Index          User Id First Name Last Name  Gender  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2           3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3           4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4           5  9C4Df1246ddf543     Angela      Shea    Male
# ...       ...              ...        ...       ...     ...
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# ...

# %% [markdown]
# #loc work with value

# %%
people.loc[[1,5]]
# Out:
#    Index          User Id First Name Last Name Gender  \
# 1      2  D781D28b845Ab9D       Dale  Mcknight   Male
# 5      6  Ca64cDbaCE8E509     Edward     Marsh   Male
#
#                         Email         Phone Date of birth  \
# 1  clairebradshaw@example.org    9062423229    1931-01-31
# 5      terrygregg@example.org  102.278.4475    1961-09-29
#
#                        Job Title
# 1  Development worker, community
# 5                     Counsellor

# %%
people.loc[[1]]
# Out:
#    Index          User Id First Name Last Name Gender  \
# 1      2  D781D28b845Ab9D       Dale  Mcknight   Male
#
#                         Email       Phone Date of birth  \
# 1  clairebradshaw@example.org  9062423229    1931-01-31
#
#                        Job Title
# 1  Development worker, community

# %%
people.loc[[1,5]]
# Out:
#    Index          User Id First Name Last Name Gender  \
# 1      2  D781D28b845Ab9D       Dale  Mcknight   Male
# 5      6  Ca64cDbaCE8E509     Edward     Marsh   Male
#
#                         Email         Phone Date of birth  \
# 1  clairebradshaw@example.org    9062423229    1931-01-31
# 5      terrygregg@example.org  102.278.4475    1961-09-29
#
#                        Job Title
# 1  Development worker, community
# 5                     Counsellor

# %%
people.loc[[1,5],["First Name","Last Name"]]
# Out:
#   First Name Last Name
# 1       Dale  Mcknight
# 5     Edward     Marsh

# %%
people.loc[[1,5],["First Name","Last Name","Email"]]
# Out:
#   First Name Last Name                       Email
# 1       Dale  Mcknight  clairebradshaw@example.org
# 5     Edward     Marsh      terrygregg@example.org

# %%
people.loc[[3,9],["First Name","Last Name"]]
# Out:
#   First Name Last Name
# 3      Karen   Everett
# 9       Jean   Ferrell

# %% [markdown]
# notice yaha pe 1:5 ke liye bada wala racket nhi lagaye hai

# %%
people.loc[1:5,["First Name","Last Name"]]       #1 se 5 tak aaya hai 5 included
# Out:
#   First Name Last Name
# 1       Dale  Mcknight
# 2    Herbert      Bean
# 3      Karen   Everett
# 4     Angela      Shea
# 5     Edward     Marsh

# %%
people.loc[1:5,[people["Gender"]="Male"]]
# Out:
#   Cell In[84], line 1
#     people.loc[1:5,[people["Gender"]="Male"]]
#                     ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
people
# Out:
#         Index          User Id First Name Last Name  Gender  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight    Male
# 2           3  eda7EcaF87b2D80    Herbert      Bean  Female
# 3           4  E75ACea5D7AeC3e      Karen   Everett  Female
# 4           5  9C4Df1246ddf543     Angela      Shea    Male
# ...       ...              ...        ...       ...     ...
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes    Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson    Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson    Male
# 99998   99999  fA585A02f6A86C5    Felicia   Robbins  Female
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle    Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# ...

# %% [markdown]
# Again yaha row aur column dono me : ye use kiye hai par brackey extra lagana nhi pada

# %%
people.loc[:6,"Email":"Job Title"]
# Out:
#                         Email                  Phone Date of birth  \
# 0     clintongood@example.org           360-423-5286    1972-01-17
# 1  clairebradshaw@example.org             9062423229    1931-01-31
# 2    johnnybooker@example.org  001-149-154-0679x1617    2018-02-10
# 3           wkhan@example.org     870.294.7563x20939    1938-06-14
# 4  reginaldgarner@example.com           242.442.2978    1971-11-22
# 5      terrygregg@example.org           102.278.4475    1961-09-29
# 6         sonya81@example.org   +1-355-400-9148x9713    2008-10-20
#
#                             Job Title
# 0             Teacher, primary school
# 1       Development worker, community
# 2                   Ceramics designer
# 3          Civil engineer, consulting
# 4           Health and safety adviser
# 5                          Counsellor
# 6  Logistics and distribution manager

# %% [markdown]
# last argument step ka hai ki kitne kitne step ke baad show kre column agar row wale me laga denge :2 to waha bhi 2 2 ke step pe aayega

# %%
people.loc[:6,"Email":"Job Title":2]
# Out:
#                         Email Date of birth
# 0     clintongood@example.org    1972-01-17
# 1  clairebradshaw@example.org    1931-01-31
# 2    johnnybooker@example.org    2018-02-10
# 3           wkhan@example.org    1938-06-14
# 4  reginaldgarner@example.com    1971-11-22
# 5      terrygregg@example.org    1961-09-29
# 6         sonya81@example.org    2008-10-20

# %%
people.loc[:6:2,"Email":"Job Title":2]
# Out:
#                         Email Date of birth
# 0     clintongood@example.org    1972-01-17
# 2    johnnybooker@example.org    2018-02-10
# 4  reginaldgarner@example.com    1971-11-22
# 6         sonya81@example.org    2008-10-20
