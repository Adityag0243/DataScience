# %%
import pandas as pd
employees_df = pd.DataFrame({
    'EmpID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Charlie']
})

salaries_df = pd.DataFrame({
    'EmployeeRef': [102, 103, 104],
    'Salary': [70000, 80000, 90000]
})


# our matching columns are empid and employeeref but their name(label) are different so we need to tell by 
# left_on and right_on


joined_df = pd.merge(employees_df, salaries_df, left_on='EmpID', right_on='EmployeeRef')

joined_df
# Out:
#    EmpID     Name  EmployeeRef  Salary
# 0    102      Bob          102   70000
# 1    103  Charlie          103   80000

# %%
import pandas as pd
employees_df = pd.DataFrame({
    'EmpID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Charlie']
})

salaries_df = pd.DataFrame({
    'EmployeeRef': [102, 103, 104],
    'Salary': [70000, 80000, 90000]
})


# our matching columns are empid and employeeref but their name(label) are different so we need to tell by 
# left_on and right_on


joined_df = pd.merge(employees_df, salaries_df, left_on='EmpID', right_on='EmployeeRef',how="inner")

joined_df
# Out:
#    EmpID     Name  EmployeeRef  Salary
# 0    102      Bob          102   70000
# 1    103  Charlie          103   80000

# %%
import pandas as pd
employees_df = pd.DataFrame({
    'EmpID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Charlie']
})

salaries_df = pd.DataFrame({
    'EmployeeRef': [102, 103, 104],
    'Salary': [70000, 80000, 90000]
})


# our matching columns are empid and employeeref but their name(label) are different so we need to tell by 
# left_on and right_on


joined_df = pd.merge(employees_df, salaries_df, left_on='EmpID', right_on='EmployeeRef',how="left")


#here i use how = left which means it will take all data from left(above dataframe) and
# common part from right


joined_df
# Out:
#    EmpID     Name  EmployeeRef   Salary
# 0    101    Alice          NaN      NaN
# 1    102      Bob        102.0  70000.0
# 2    103  Charlie        103.0  80000.0

# %%
import pandas as pd
employees_df = pd.DataFrame({
    'EmpID': [101, 102, 103],
    'Name': ['Alice', 'Bob', 'Charlie']
})

salaries_df = pd.DataFrame({
    'EmployeeRef': [102, 103, 104],
    'Salary': [70000, 80000, 90000]
})


# our matching columns are empid and employeeref but their name(label) are different so we need to tell by 
# left_on and right_on


joined_df = pd.merge(employees_df, salaries_df, left_on='EmpID', right_on='EmployeeRef',how="right")


#here i use how = left which means it will take all data from left(above dataframe) and
# common part from right


joined_df
# Out:
#    EmpID     Name  EmployeeRef  Salary
# 0  102.0      Bob          102   70000
# 1  103.0  Charlie          103   80000
# 2    NaN      NaN          104   90000

# %%
data1 = {
    'ProductID': [101, 102, 103, 104],
    'ProductName': ['Laptop', 'Smartphone', 'Headphones', 'Tablet']
}

data2 = {
    'EmployeeID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'DepartmentID': [101, 102, 103, 101]
}

type(data1)
# Out:
# dict

# %%
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

# %%
df1
# Out:
#    ProductID ProductName
# 0        101      Laptop
# 1        102  Smartphone
# 2        103  Headphones
# 3        104      Tablet

# %%
df2
# Out:
#    EmployeeID     Name  DepartmentID
# 0           1    Alice           101
# 1           2      Bob           102
# 2           3  Charlie           103
# 3           4    David           101

# %%
import pandas as pd

# %%
df1=pd.read_excel("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df1=pd.read_excel("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
df2=pd.DataFrame("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9852\545657414.py in ?()
# ----> 1 df2=pd.DataFrame("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
df=pd.DataFrame("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9852\3695926335.py in ?()
# ----> 1 df=pd.DataFrame("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     813                 )
#     814         # For data is scalar
#     815         else:
#     816             if index is None or columns is None:
# --> 817                 raise ValueError("DataFrame constructor not properly called!")
#     818
#     819             index = ensure_index(index)
#     820             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
df=pd.read_excel("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df=pd.read_excel("Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
df=pd.read_excel(Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df=pd.read_excel(Desktop/DAPython/DA_NOTES/Pandas/SampleSuperstore.xlsx)
#
# NameError: name 'Desktop' is not defined

# %%
df=pd.read_excel('SampleSuperstore.xlsx')
# Out:
# C:\Users\mradi\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
df1=pd.read_excel('SampleSuperstore.xlsx',sheet_name="Returns")
# Out:
# C:\Users\mradi\anaconda3\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df1
# Out:
#     Returned        Order ID
# 0        Yes  CA-2016-100762
# 1        Yes  CA-2016-100762
# 2        Yes  CA-2016-100762
# 3        Yes  CA-2016-100762
# 4        Yes  CA-2016-100867
# ..       ...             ...
# 795      Yes  US-2019-147886
# 796      Yes  US-2019-147998
# 797      Yes  US-2019-151127
# 798      Yes  US-2019-155999
# 799      Yes  US-2019-155999
#
# [800 rows x 2 columns]

# %%
inner_df3=pd.merge(df,df1,left_on="Order ID",right_on="Order ID")

# %%
inner_df3
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0         19  CA-2016-143336 2016-08-27 2016-09-01    Second Class
# 1         19  CA-2016-143336 2016-08-27 2016-09-01    Second Class
# 2         19  CA-2016-143336 2016-08-27 2016-09-01    Second Class
# 3         20  CA-2016-143336 2016-08-27 2016-09-01    Second Class
# 4         20  CA-2016-143336 2016-08-27 2016-09-01    Second Class
# ...      ...             ...        ...        ...             ...
# 3221    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 3222    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 3223    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 3224    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 3225    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
#
#      Customer ID       Customer Name   Segment Country/Region           City  \
# 0       ZD-21925  Zuschuss Donatelli  Consumer  United States  San Francisco
# ...

# %%
left_df3=pd.merge(df,df1,left_on="Order ID",right_on="Order ID",how="left")

# %%
left_df3
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1           2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2           3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3           4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4           5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...       ...             ...        ...        ...             ...
# 12415    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 12416    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 12417    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 12418    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 12419    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#       Customer ID    Customer Name    Segment Country/Region             City  \
# ...

# %% [markdown]
# cross join

# %%
import pandas as pd
colors_df = pd.DataFrame({
    'Color': ['Red', 'Blue', 'Green']
})


shapes_df = pd.DataFrame({
    'Shape': ['Circle', 'Square', 'Triangle']
})




# Perform a cross join
# Adding a temporary key for both DataFrames to merge on
colors_df['key'] = 1
shapes_df['key'] = 1

print(colors_df)
print()
print(shapes_df)
print()



# Executing the cross join
cross_joined_df = pd.merge(colors_df, shapes_df, on='key').drop('key', axis=1)
cross_joined_df2 = pd.merge( shapes_df,colors_df, on='key').drop('key', axis=1)






print(cross_joined_df)
print()
print(cross_joined_df2)
# Out:
#    Color  key
# 0    Red    1
# 1   Blue    1
# 2  Green    1
#
#       Shape  key
# 0    Circle    1
# 1    Square    1
# 2  Triangle    1
#
#    Color     Shape
# 0    Red    Circle
# 1    Red    Square
# 2    Red  Triangle
# 3   Blue    Circle
# 4   Blue    Square
# 5   Blue  Triangle
# 6  Green    Circle
# 7  Green    Square
# 8  Green  Triangle
#
#       Shape  Color
# 0    Circle    Red
# 1    Circle   Blue
# 2    Circle  Green
# 3    Square    Red
# 4    Square   Blue
# 5    Square  Green
# 6  Triangle    Red
# 7  Triangle   Blue
# 8  Triangle  Green

# %%
abbrevs = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv')

# %%
abbrevs
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
areas= pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv')
areas
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
pop = pd.read_csv('https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv')
pop
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]

# %%
data1=pd.merge(abbrevs,areas)

# %%
data1
# Out:
#                    state abbreviation  area (sq. mi)
# 0                Alabama           AL          52423
# 1                 Alaska           AK         656425
# 2                Arizona           AZ         114006
# 3               Arkansas           AR          53182
# 4             California           CA         163707
# 5               Colorado           CO         104100
# 6            Connecticut           CT           5544
# 7               Delaware           DE           1954
# 8   District of Columbia           DC             68
# 9                Florida           FL          65758
# 10               Georgia           GA          59441
# 11                Hawaii           HI          10932
# 12                 Idaho           ID          83574
# 13              Illinois           IL          57918
# 14               Indiana           IN          36420
# 15                  Iowa           IA          56276
# 16                Kansas           KS          82282
# ...

# %%
data=pd.merge(data1,pop,left_on="abbreviation",right_on="state/region")

# %%
data
# Out:
#         state abbreviation  area (sq. mi) state/region     ages  year  \
# 0     Alabama           AL          52423           AL  under18  2012
# 1     Alabama           AL          52423           AL    total  2012
# 2     Alabama           AL          52423           AL  under18  2010
# 3     Alabama           AL          52423           AL    total  2010
# 4     Alabama           AL          52423           AL  under18  2011
# ...       ...          ...            ...          ...      ...   ...
# 2443  Wyoming           WY          97818           WY  under18  1993
# 2444  Wyoming           WY          97818           WY    total  1991
# 2445  Wyoming           WY          97818           WY  under18  1991
# 2446  Wyoming           WY          97818           WY  under18  1990
# 2447  Wyoming           WY          97818           WY    total  1990
#
#       population
# 0      1117489.0
# 1      4817528.0
# 2      1130966.0
# 3      4785570.0
# 4      1125763.0
# ...

# %%
data['ages'].unique()
# Out:
# array(['under18', 'total'], dtype=object)

# %%
data_groupby_year=data.groupby(['year','abbreviation']).agg({'area (sq. mi)':'mean','population':'mean'})

# %%
data_groupby_year
# Out:
#                    area (sq. mi)  population
# year abbreviation
# 1990 AK                 656425.0    365396.0
#      AL                  52423.0   2550048.0
#      AR                  53182.0   1488759.5
#      AZ                 114006.0   2345068.5
#      CA                 163707.0  18970008.0
# ...                          ...         ...
# 2013 VT                   9615.0    374665.5
#      WA                  71303.0   4283600.5
#      WI                  65503.0   3525244.5
#      WV                  24231.0   1117991.0
#      WY                  97818.0    360168.5
#
# [1224 rows x 2 columns]
